# %% [markdown]
# Homework 1 Problem 2: Pyrolysis of Ethane
# ==================

# %%
import pandas as pd
import numpy as np
import time
import cantera as ct
from matplotlib import pyplot as plt
import csv
import math
import os


from IPython.display import Image

print("Running Cantera version: {}".format(ct.__version__))
# Out:
# Running Cantera version: 2.4.0

# %% [markdown]
# Problem 2 A
# --------

# %% [markdown]
# a)Now simulate a system of pure ethane (no initial H atoms) at 1000 K and 1 atm. This is one of the most important and largest-volume commercial chemical reactions; ethane is a major component in natural gas, and the desired product ethene (C2H4) is the key ingredient used for making many man-made materials. Run the simulation until the mole fraction of ethane has dropped approximately in half.
#
# i) what is its half-life in this system?
#
# ii) Plot the log of the C2H6 mole fraction versus time – is it a straight line, or not?
#
# iii) Is C2H6 decay a pseudo-first-order process?

# %%
# get chemkin file and setup reactor
cti_file = '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/propanepyrolysis.cti'
gas = ct.Solution(cti_file)

# start with pure ethane:
X_Eth = 1

# Reactor conditions
reactorTemperature = 1000  # Kelvin
reactorPressure = ct.one_atm 
concentrations = {'C2H6(36)': X_Eth}
gas.TPX = reactorTemperature, reactorPressure, concentrations 
Eth_conc = gas['C2H6(36)'].concentrations
Eth_conc_half = Eth_conc/2

#initialize reactor, reactor network and sensitivities
atol = 1e-23
rtol = 1e-8
r1 = ct.ConstPressureReactor(contents=gas, energy='off', name='isothermal_reactor')

sim = ct.ReactorNet([r1])
sim.atol = atol
sim.rtol = rtol
for i in range(gas.n_reactions):
     r1.add_sensitivity_reaction(i)

#check initial concentration
print('Initial Ethane concentration:', Eth_conc,'\nHalf of initial concentration:', Eth_conc_half)
# Out:
# Initial Ethane concentration: [0.0121866]
# Half of initial concentration: [0.0060933]

# %%
# Run the reactor
time = 2
sim.reinitialize()

# make a second file for net rates of progress (kmol/M^3)
gas.net_rates_of_progress

# Create output files for sim that we can read in later:
outfile = open('results_ethane','w')
outfile2 = open('results_ethane_ROP','w')
outfile3 = open('results_sensitivity', 'w')
gas_production_label = [s + ' production rate' for s in gas.species_names]
gas_concentration_label = [s + ' concentration' for s in gas.species_names]
writer = csv.writer(outfile)
writer2 = csv.writer(outfile2)
writer3 = csv.writer(outfile3)
writer.writerow(['Time (s)'] + gas.species_names + gas_concentration_label + gas_production_label)
writer2.writerow(['Time (s)'] + gas.reactions())
writer3.writerow(['Time (s)'] + gas.reactions())

while gas['C2H6(36)'].concentrations >= 0.005:
    sim.step()
    writer.writerow([sim.time] + list(gas.X) + list(gas.concentrations)+list(gas.net_production_rates))
    writer2.writerow([sim.time] + list(gas.net_rates_of_progress))
    writer3.writerow([sim.time] + [sim.sensitivity('C2H6(36)', s) for s in range(gas.n_reactions)])

# %%
# added functions for flux diagram generation

def save_flux_diagrams(*phases, suffix=''):
    """
    Saves the flux diagrams. The filenames have a suffix if provided,
    so you can keep them separate and not over-write.
    """
    for element in 'CH':
        for phase_object in phases:
            phase = phase_object.name

            diagram = ct.ReactionPathDiagram(phase_object, element)
            diagram.title = f'Reaction path diagram following {element} in {phase}'
            diagram.label_threshold = 0.01

            dot_file = f"reaction_path_{element}_{phase}{'_' if suffix else ''}{suffix}.dot"
            img_file = f"reaction_path_{element}_{phase}{'_' if suffix else ''}{suffix}.png"
            img_path = os.path.join(os.getcwd(), img_file)
            diagram.write_dot(dot_file)
            #print(diagram.get_data())

            print(f"Wrote graphviz input file to '{os.path.join(os.getcwd(), dot_file)}'.")
            os.system(f'dot {dot_file} -Tpng -o{img_file} -Gdpi=200')
            print(f"Wrote graphviz output file to '{img_path}'.")

def show_flux_diagrams(*phases, suffix='', embed=False):
    """
    Shows the flux diagrams in the notebook.
    Loads them from disk.
    Does not embed them, to keep the .ipynb file small,
    unless embed=True. Use embed=True if you might over-write the files,
    eg. you want to show flux at different points.
    """
    import IPython
    for element in 'CH':
        for phase_object in phases:
            phase = phase_object.name
            img_file = f"reaction_path_{element}_{phase}{'_' if suffix else ''}{suffix}.png"
            display(IPython.display.HTML(f'<hr><h2>{element} {phase}</h2>'))
            if embed:
                display(IPython.display.Image(filename=img_file,width=400,embed=True))
            else:
                display(IPython.display.Image(url=img_file,width=400,embed=False))

# %%
# Generate and save flux diagrams after sim
save_flux_diagrams(gas)
# Out:
# Wrote graphviz input file to '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/Cantera Notebook/reaction_path_C_gas.dot'.
# Wrote graphviz output file to '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/Cantera Notebook/reaction_path_C_gas.png'.
# Wrote graphviz input file to '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/Cantera Notebook/reaction_path_H_gas.dot'.
# Wrote graphviz output file to '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/Cantera Notebook/reaction_path_H_gas.png'.

# %%
data = pd.read_csv('results_ethane')
df = pd.DataFrame(data)
data_rop = pd.read_csv('results_ethane_ROP')
df_rop = pd.DataFrame(data_rop)
data_sens = pd.read_csv('results_sensitivity')
df_sens = pd.DataFrame(data_sens)

# %% [markdown]
# ##### Problem 2.A.i #####
# Now simulate a system of pure ethane (no initial H atoms) at 1000 K and 1 atm. This is one of the most important and largest-volume commercial chemical reactions; ethane is a major component in natural gas, and the desired product ethene (C2H4) is the key ingredient used for making many man-made materials. Run the simulation until the mole fraction of ethane has dropped approximately in half.
#
# i) what is its half-life in this system?

# %%
timecol = df[df.columns[0]]
Ethcol = df['C2H6(36) concentration']

for i in range (0, len(timecol)):
    if Ethcol[i] <= Eth_conc_half:
        # perform 2-point interpolation to get half life time
        y1 = timecol[i-1]
        y2 = timecol[i]
        x1 = Ethcol[i-1]
        x2 = Ethcol[i]
        t_halflife = ((y2-y1)/(x2-x1))*(Eth_conc_half-x1)+y1
        print("Problem 2.A.i: Halflife of Ethane is", t_halflife, "seconds")
        break
# Out:
# Problem 2.A.i: Halflife of Ethane is [2.32255056] seconds

# %%
# problem 2.A.ii
# Plot the log of the C2H6 mole fraction versus time – is it a straight line, or not? 

# lets see. We'll set the max of the x-axis to t_halflife for the ethane mole fraction:
plt1 = data.plot(x='Time (s)', y='C2H6(36)')
plt1.set_xlim(0,4.6)
plt.ylabel('Mole fraction Ethane Molecule')
plt.xlabel('Time (s)')
plt.show()

# %%
# problem 2.A.iii
# Is C2H6 decay a pseudo-first-order process?
# no

# %%
# problem 2.B.i
# Make a Flux Diagram at that time-point and from it and ROP analyses write down the main sequence of 
# balanced reactions that is converting C2H6 into C2H4. What is the main reaction consuming C2H6 at that time point??


imp_reactions = []

print('\nThese are all the reactions that report ROP value above the threshold of 1E-4 kmol/m^3:', '\n')
for i in range (1, len(df_rop.columns)):
    
    column = df_rop[df_rop.columns[i]]
    time = df_rop[df.columns[0]]
    max_value = column.max()
    max_index = column.idxmax()

    if max_value > 1e-5:
        imp_reactions.append(df_rop.columns[i])
        print(df_rop.columns[i], "Max = " "{:.10f}".format(max_value),'  time = ', time[max_index], 'column:', i)
        


Image(filename='reaction_path_H_gas.png')

# it appears the main reaction sequence is:
# C2H6(36) + CH3(14) <=> C2H5(37) + CH4(15)
# 2 C2H5(37) <=> C2H4(38) + C2H6(36)
# Out:
# These are all the reactions that report ROP value above the threshold of 1E-4 kmol/m^3:
#
# C2H6(36) + CH3(14) <=> C2H5(37) + CH4(15) Max = 0.0000403637   time =  0.4606184114053114 column: 12
# 2 C2H5(37) <=> C2H4(38) + C2H6(36) Max = 0.0000119301   time =  0.011768166117452359 column: 15
# C2H6(36) + H(2) <=> C2H5(37) + H2(6) Max = 0.0044383692   time =  0.010280131592666565 column: 26
# SC4H9(184) <=> C3H6(95) + CH3(14) Max = 0.0000149771   time =  1.6663567650657358 column: 69
# C2H4(38) + H(2) <=> C2H3(41) + H2(6) Max = 0.0000120472   time =  0.7678006487802125 column: 210

# %% [markdown]
# (c)Do a sensitivity analysis at that time-point to see which rate coefficients affect the predicted mole-fraction of C2H6.
#
# i) Is the conversion of C2H6 very sensitive to the main reaction you identified in part (b)?
#
# ii) Is the conversion of C2H6 more sensitive to other reaction(s) in the main sequence?
#
# iii) Does the sensitivity analysis identify any reactions as being important that do not show up at all in Part
# (b)? What are these extra reactions doing?

# %%
# sensitivity analysis: 
# !!!!!!!
# i. and ii. need written answers

for i in range(len(imp_reactions)):
    df_sens.plot(x='Time (s)', y=sens_rxns[i])

# %%
# iii) Does the sensitivity analysis identify any reactions as being important that do not show up at all in 
# Part (b)? What are these extra reactions doing?
time = df_sens[df_sens.columns[0]]

sens_rxns=[]

for i in range (1, len(df_sens.columns)):
    column = df_sens[df_sens.columns[i]]
    column_mean_abs = abs(column.mean())
    
    if column_mean_abs > 1e-2:
        print(df_sens.columns[i], ':', column.mean(), 'MEAN', 'Column:', i)
        sens_rxns.append(df_sens.columns[i])
        
    if column.max() > 1e-2:
        print(df_sens.columns[i], ':', column.max(), 'MAX', 'Column:', i)
        if column_mean_abs <= 1e-2:
            sens_rxns.append(df_sens.columns[i])
        
    if column.min() < -1e-2:
        print(df_sens.columns[i], ':', column.min(), 'MIN', 'Column:', i)
        if column_mean_abs <= 1e-2:
            sens_rxns.append(df_sens.columns[i])

for i in range(len(sens_rxns)):
    df_sens.plot(x='Time (s)', y=sens_rxns[i])
    

# additional reactions identified. it appears that these reactions are generating CH3(14), 
# used in the main reaction; C2H5(37), an intermediate to C2H4; or is consuming/generating H(2) & C2H4.
# I think these are all contributing to the reaction path to CH3(14), which will eventually form methane. 

# propane(1) (+M) <=> C2H5(37) + CH3(14) (+M)
# 2 CH3(14) (+M) <=> C2H6(36) (+M)
# C2H4(38) + H(2) (+M) <=> C2H5(37) (+M)
# C3H5-A(94) + CH3(14) (+M) <=> C4H8(189) (+M)
# C2H5(37) + C4H7(191) <=> C2H6(36) + C4H6(195)
# C2H5(37) + C4H7(191) <=> C2H4(38) + C4H8(190)
# C4H6(195) + H(2) <=> C2H3(41) + C2H4(38)
# Out:
# propane(1) (+M) <=> C2H5(37) + CH3(14) (+M) : 0.014443794703680204 MAX Column: 1
# 2 CH3(14) (+M) <=> C2H6(36) (+M) : -0.032840947837607014 MEAN Column: 11
# 2 CH3(14) (+M) <=> C2H6(36) (+M) : -0.09259898350224784 MIN Column: 11
# C2H6(36) + CH3(14) <=> C2H5(37) + CH4(15) : -0.013688783131342518 MIN Column: 12
# 2 C2H5(37) <=> C2H4(38) + C2H6(36) : 0.01777526495149359 MEAN Column: 15
# 2 C2H5(37) <=> C2H4(38) + C2H6(36) : 0.046887298225694214 MAX Column: 15
# C2H4(38) + H(2) (+M) <=> C2H5(37) (+M) : -0.04804214463422429 MEAN Column: 18
# C2H4(38) + H(2) (+M) <=> C2H5(37) (+M) : -0.1211163699202442 MIN Column: 18
# C2H6(36) + H(2) <=> C2H5(37) + H2(6) : -0.027208461667401394 MEAN Column: 26
# C2H6(36) + H(2) <=> C2H5(37) + H2(6) : -0.1161894888034242 MIN Column: 26
# C3H5-A(94) + CH3(14) (+M) <=> C4H8(189) (+M) : -0.017178733954354788 MIN Column: 72
# C2H5(37) + C4H7(191) <=> C2H6(36) + C4H6(195) : 0.012230170708367152 MAX Column: 106
# C2H5(37) + C4H7(191) <=> C2H4(38) + C4H8(190) : 0.015521193353294629 MAX Column: 123
# C2H4(38) + H(2) <=> C2H3(41) + H2(6) : 0.02034096247883756 MAX Column: 210
# C4H6(195) + H(2) <=> C2H3(41) + C2H4(38) : 0.016591085666531842 MAX Column: 223

# %% [markdown]
# 2.D.i Run this reaction at P=2 atm, pure ethane
#
# i) If you run this reaction at P=2 atm, pure ethane, is the half-life of ethane longer or shorter than at P=1 atm? Why?

# %%
# get chemkin file and setup reactor
cti_file = '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/propanepyrolysis.cti'
gas = ct.Solution(cti_file)

# start with pure ethane:
X_Eth = 1

# Reactor conditions
reactorTemperature = 1000  # Kelvin
reactorPressure = ct.one_atm*2 #change pressure to  
concentrations = {'C2H6(36)': X_Eth}
gas.TPX = reactorTemperature, reactorPressure, concentrations 
Eth_conc = gas['C2H6(36)'].concentrations
Eth_conc_half = Eth_conc/2

#initialize reactor, reactor network and sensitivities
atol = 1e-23
rtol = 1e-8
r1 = ct.ConstPressureReactor(contents=gas, energy='off', name='isothermal_reactor')

sim = ct.ReactorNet([r1])
sim.atol = atol
sim.rtol = rtol
for i in range(gas.n_reactions):
     r1.add_sensitivity_reaction(i)

#check initial concentration
print('Initial Ethane concentration:', Eth_conc,'\nHalf of initial concentration:', Eth_conc_half)

# Run the reactor
time = 2
sim.reinitialize()

# make a second file for net rates of progress (kmol/M^3)
gas.net_rates_of_progress

# Create output files for sim that we can read in later:
outfile = open('results_ethane_2atm','w')
outfile2 = open('results_ethane_ROP_2atm','w')
outfile3 = open('results_sensitivity_2atm', 'w')
gas_production_label = [s + ' production rate' for s in gas.species_names]
gas_concentration_label = [s + ' concentration' for s in gas.species_names]
writer = csv.writer(outfile)
writer2 = csv.writer(outfile2)
writer3 = csv.writer(outfile3)
writer.writerow(['Time (s)'] + gas.species_names + gas_concentration_label + gas_production_label)
writer2.writerow(['Time (s)'] + gas.reactions())
writer3.writerow(['Time (s)'] + gas.reactions())

while gas['C2H6(36)'].concentrations >= Eth_conc_half:
    sim.step()
    print(sim.time)
    writer.writerow([sim.time] + list(gas.X) + list(gas.concentrations)+list(gas.net_production_rates))
    writer2.writerow([sim.time] + list(gas.net_rates_of_progress))
    writer3.writerow([sim.time] + [sim.sensitivity('C2H6(36)', s) for s in range(gas.n_reactions)])
# Out:
# Initial Ethane concentration: [0.02437319]
# Half of initial concentration: [0.0121866]
# 1.2637793542094199e-17
# 1.2639057321448408e-13
# 5.416910000867705e-13
# 9.569914269590569e-13
# 1.3722918538313433e-12
# 1.9991641710592673e-12
# 3.0278071055369618e-12
# 4.777471817376857e-12
# 7.791897878310189e-12
# 1.3011854537522961e-11
# 2.2094779223786636e-11
# 3.818425799518893e-11
# 6.99147862575629e-11
# 1.0164531451993687e-10
# 1.3337584278231085e-10
# 1.8679190110146907e-10
# 2.402079594206273e-10
# 2.936240177397855e-10
# 3.4704007605894374e-10
# 4.585531116909397e-10
# 6.277025679162072e-10
# 7.968520241414746e-10
# 9.66001480366742e-10
# 1.1351509365920095e-09
# 1.3988532621523823e-09
# 1.6625555877127551e-09
# 1.926257913273128e-09
# 2.48007506174111e-09
# 3.033892210209092e-09
# 3.587709358677074e-09
# 4.141526507145057e-09
# 4.695343655613039e-09
# 5.624831195994593e-09
# 6.554318736376147e-09
# 7.483806276757701e-09
# 8.413293817139255e-09
# 9.342781357520809e-09
# 1.0272268897902363e-08
# 1.1936141471227314e-08
# 1.3600014044552264e-08
# 1.5263886617877213e-08
# 1.6927759191202164e-08
# 1.8591631764527114e-08
# 2.0255504337852065e-08
# 2.1919376911177015e-08
# 2.3583249484501966e-08
# 2.5247122057826916e-08
# 2.8029321495014275e-08
# 3.081152093220164e-08
# 3.3593720369389e-08
# 3.6375919806576356e-08
# 3.9158119243763715e-08
# 4.1940318680951074e-08
# 4.472251811813843e-08
# 4.750471755532579e-08
# 5.028691699251315e-08
# 5.306911642970051e-08
# 5.585131586688787e-08
# 5.863351530407523e-08
# 6.141571474126259e-08
# 2.775698520342101
# 2.78416104341528
# 2.7926235664884587
# 2.8010860895616374
# 2.809548612634816
# 2.815379436008243
# 2.8212102593816697
# 2.8270410827550965
# 2.8328719061285232
# 2.83870272950195
# 2.8425631610363875
# 2.845103299951323
# 2.8468720649379424
# 2.848640829924562
# 2.8504095949111816
# 2.852178359897801
# 2.853947124884421
# 2.8574655616755003
# 2.8609839984665797
# 2.864502435257659
# 2.8717556246229248
# 2.8907903184206836
# 2.9098250122184424
# 2.938455978599913
# 2.9670869449813835
# 2.995717911362854
# 3.0243488777443246
# 3.052979844125795
# 3.0816108105072657
# 3.1102417768887363
# 3.138872743270207
# 3.1675037096516774
# 3.196134676033148
# 3.2247656424146185
# 3.253396608796089
# 3.2820275751775596
# 3.31065854155903
# 3.3392895079405007
# 3.3679204743219713
# 3.396551440703442
# 3.4251824070849124
# 3.453813373466383
# 3.4824443398478535
# 3.511075306229324

# %%
data_2atm = pd.read_csv('results_ethane_2atm')
df_2atm = pd.DataFrame(data_2atm)
data_rop_2atm = pd.read_csv('results_ethane_ROP_2atm')
df_rop_2atm = pd.DataFrame(data_rop_2atm)
data_sens_2atm = pd.read_csv('results_sensitivity_2atm')
df_sens_2atm = pd.DataFrame(data_sens_2atm)

# %%
# what is its (Ethane's) half-life in this system? 

timecol = df_2atm[df_2atm.columns[0]]
Ethcol = df_2atm['C2H6(36) concentration']

for i in range (0, len(timecol)):
    if Ethcol[i] <= Eth_conc_half:
        # perform 2-point interpolation to get half life time
        y1 = timecol[i-1]
        y2 = timecol[i]
        x1 = Ethcol[i-1]
        x2 = Ethcol[i]
        t_halflife_2atm = ((y2-y1)/(x2-x1))*(Eth_conc_half-x1)+y1
        print("Problem 2.A.i: Halflife of Ethane is", t_halflife_2atm, "seconds at 2 atm")
        print("Problem 2.A.i: Halflife of Ethane is", t_halflife, "seconds at 1 atm")
        break  
        
# the halflife is about 1 second longer. some of the reactions that we saw as sensitive in the previous analysis 
# were 3 body reactions (as denoted by the M+ reactant). these reactions will have a greater rate at higher 
# pressures, taking away from the main reaction sequence.
# Out:
# Problem 2.A.i: Halflife of Ethane is [3.48320812] seconds at 2 atm
# Problem 2.A.i: Halflife of Ethane is [2.32255056] seconds at 1 atm

# %% [markdown]
# (e)Run this reaction at P=2 atm, with the initial composition at 50% ethane and 50% He
#
# i) Is the ethane half-life longer or shorter or the same as the case with pure ethane at P=1 atm? Note that in these two cases the initial concentration of ethane is identical. Also note that the He is completely inert.
#
# ii) Speculate about what is causing any difference between the two cases.

# %%
# get chemkin file and setup reactor
cti_file = '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/propanepyrolysis.cti'
gas = ct.Solution(cti_file)

# start with pure ethane:
X_Eth = 0.5
X_He = 0.5

# Reactor conditions
reactorTemperature = 1000  # Kelvin
reactorPressure = ct.one_atm*2 #change pressure to  
concentrations = {'C2H6(36)': X_Eth, 'He': X_He}
gas.TPX = reactorTemperature, reactorPressure, concentrations 
Eth_conc = gas['C2H6(36)'].concentrations
Eth_conc_half = Eth_conc/2

#initialize reactor, reactor network and sensitivities
atol = 1e-23
rtol = 1e-8
r1 = ct.ConstPressureReactor(contents=gas, energy='off', name='isothermal_reactor')

sim = ct.ReactorNet([r1])
sim.atol = atol
sim.rtol = rtol
for i in range(gas.n_reactions):
     r1.add_sensitivity_reaction(i)

#check initial concentration
print('Initial Ethane concentration:', Eth_conc,'\nHalf of initial concentration:', Eth_conc_half)

# Run the reactor
time = 2
sim.reinitialize()

# make a second file for net rates of progress (kmol/M^3)
gas.net_rates_of_progress

# Create output files for sim that we can read in later:
outfile = open('results_ethane_2atm_He','w')
outfile2 = open('results_ethane_ROP_2atm_He','w')
outfile3 = open('results_sensitivity_2atm_He', 'w')
gas_production_label = [s + ' production rate' for s in gas.species_names]
gas_concentration_label = [s + ' concentration' for s in gas.species_names]
writer = csv.writer(outfile)
writer2 = csv.writer(outfile2)
writer3 = csv.writer(outfile3)
writer.writerow(['Time (s)'] + gas.species_names + gas_concentration_label + gas_production_label)
writer2.writerow(['Time (s)'] + gas.reactions())
writer3.writerow(['Time (s)'] + gas.reactions())

while gas['C2H6(36)'].concentrations >= Eth_conc_half:
    sim.step()
    print(sim.time)
    writer.writerow([sim.time] + list(gas.X) + list(gas.concentrations)+list(gas.net_production_rates))
    writer2.writerow([sim.time] + list(gas.net_rates_of_progress))
    writer3.writerow([sim.time] + [sim.sensitivity('C2H6(36)', s) for s in range(gas.n_reactions)])
# Out:
# Initial Ethane concentration: [0.0121866]
# Half of initial concentration: [0.0060933]
# 1.3452638902840721e-17
# 1.3453984166731006e-13
# 6.92059299036149e-13
# 1.249578756404988e-12
# 1.807098213773827e-12
# 2.717589639223911e-12
# 4.248400343509588e-12
# 6.876258715714155e-12
# 1.1418141816932792e-11
# 1.9289795006444322e-11
# 3.297512625312451e-11
# 5.706163518070302e-11
# 1.024809016128429e-10
# 1.8881841193112534e-10
# 2.751559222494078e-10
# 3.6149343256769026e-10
# 4.478309428859727e-10
# 6.040322181657547e-10
# 7.602334934455367e-10
# 9.164347687253187e-10
# 1.0726360440051007e-09
# 1.2288373192848826e-09
# 1.5289335354227422e-09
# 1.981307358639902e-09
# 2.433681181857062e-09
# 2.8860550050742215e-09
# 3.338428828291381e-09
# 3.790802651508541e-09
# 4.580161083160585e-09
# 5.3695195148126294e-09
# 6.578595045660716e-09
# 7.787670576508803e-09
# 8.99674610735689e-09
# 1.0205821638204976e-08
# 1.1414897169053063e-08
# 1.3741345784097638e-08
# 1.6067794399142213e-08
# 1.839424301418679e-08
# 2.0720691629231363e-08
# 2.3047140244275937e-08
# 2.537358885932051e-08
# 2.7700037474365084e-08
# 3.002648608940966e-08
# 3.235293470445423e-08
# 3.4679383319498805e-08
# 3.882872972381899e-08
# 4.297807612813917e-08
# 4.7127422532459354e-08
# 5.127676893677954e-08
# 5.542611534109972e-08
# 5.9575461745419904e-08
# 6.372480814974009e-08
# 6.787415455406027e-08
# 7.202350095838045e-08
# 7.617284736270064e-08
# 8.032219376702082e-08
# 8.4471540171341e-08
# 8.862088657566119e-08
# 2.297134519968732
# 2.2986798847923677
# 2.3002252496160036
# 2.3017706144396395
# 2.304369801403894
# 2.306968988368148
# 2.3095681753324024
# 2.3149896630694586
# 2.3281869282687584
# 2.341384193468058
# 2.3626289652985113
# 2.3838737371289644
# 2.4051185089594176
# 2.4263632807898707
# 2.447608052620324
# 2.468852824450777
# 2.50242641549959
# 2.536000006548403
# 2.5695735975972163
# 2.6031471886460293
# 2.6367207796948424
# 2.6702943707436555
# 2.7038679617924686
# 2.7374415528412817
# 2.7710151438900947
# 2.804588734938908
# 2.838162325987721
# 2.871735917036534
# 2.905309508085347
# 2.93888309913416
# 2.972456690182973
# 3.0060302812317863
# 3.0396038722805994
# 3.0630612744215817
# 3.079182527306818
# 3.0953037801920544
# 3.111425033077291
# 3.127546285962527
# 3.1436675388477635
# 3.159788791733
# 3.1759100446182362
# 3.187090901003997
# 3.198271757389758
# 3.209452613775519
# 3.22063347016128
# 3.231814326547041
# 3.242995182932802
# 3.254176039318563
# 3.2653568957043237
# 3.2765377520900847
# 3.2841194731044516
# 3.289166824640389
# 3.2942141761763266
# 3.299261527712264
# 3.3043088792482016
# 3.309356230784139
# 3.317516702405624
# 3.3256771740271085
# 3.333837645648593
# 3.3499038546961133
# 3.3794824108347283
# 3.4090609669733434
# 3.4386395231119584
# 3.4682180792505735
# 3.4977966353891885
# 3.5273751915278035
# 3.5569537476664186
# 3.5865323038050336
# 3.6161108599436487
# 3.6456894160822637
# 3.691800803586389
# 3.7379121910905146
# 3.78402357859464
# 3.8301349660987656
# 3.876246353602891

# %%
data_2atm_He = pd.read_csv('results_ethane_2atm_He')
df_2atm_He = pd.DataFrame(data_2atm_He)
data_rop_2atm_He = pd.read_csv('results_ethane_ROP_2atm_He')
df_rop_2atm_He = pd.DataFrame(data_rop_2atm_He)
data_sens_2atm_He = pd.read_csv('results_sensitivity_2atm_He')
df_sens_2atm_He = pd.DataFrame(data_sens_2atm_He)

# %%
# what is its (Ethane's) half-life in this system? 

timecol = df_2atm_He[df_2atm_He.columns[0]]
Ethcol = df_2atm_He['C2H6(36) concentration']

for i in range (0, len(timecol)):
    if Ethcol[i] <= Eth_conc_half:
        # perform 2-point interpolation to get half life time
        y1 = timecol[i-1]
        y2 = timecol[i]
        x1 = Ethcol[i-1]
        x2 = Ethcol[i]
        t_halflife_2atm_He = ((y2-y1)/(x2-x1))*(Eth_conc_half-x1)+y1
        print("Problem 2.A.i: Halflife of Ethane is", t_halflife_2atm_He, "seconds at 2 atm")
        print("Problem 2.A.i: Halflife of Ethane is", t_halflife, "seconds at 1 atm")
        break  
        
# the halflife is about even longer than the 2 atm reactor without He. some of the reactions that we saw as 
# sensitive in the previous analysis were 3 body reactions (as denoted by the M+ reactant). with the addition of 
# He, we now have a greater concentration of colliders that can participate in the M+ reactions.
# Out:
# Problem 2.A.i: Halflife of Ethane is [3.84488363] seconds at 2 atm
# Problem 2.A.i: Halflife of Ethane is [2.32255056] seconds at 1 atm

# %% [markdown]
# (f)One expects the reaction kinetics to lead to chemical equilibrium. What is the equilibrium distribution of the species in the model, if one starts from pure ethane, and holds the system at 1000 K and 1 atm?

# %%
# get chemkin file and setup reactor
cti_file = '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/propanepyrolysis.cti'
gas = ct.Solution(cti_file)

# start with pure ethane:
X_Eth = 1

# Reactor conditions
reactorTemperature = 1000  # Kelvin
reactorPressure = ct.one_atm
concentrations = {'C2H6(36)': X_Eth}
gas.TPX = reactorTemperature, reactorPressure, concentrations 
Eth_conc = gas['C2H6(36)'].concentrations
Eth_conc_half = Eth_conc/2

#initialize reactor, reactor network and sensitivities
atol = 1e-23
rtol = 1e-8
r1 = ct.ConstPressureReactor(contents=gas, energy='off', name='isothermal_reactor')

sim = ct.ReactorNet([r1])
sim.atol = atol
sim.rtol = rtol
for i in range(gas.n_reactions):
     r1.add_sensitivity_reaction(i)

#check initial concentration
print('Initial Ethane concentration:', Eth_conc,'\nHalf of initial concentration:', Eth_conc_half)

# Run the reactor
sim.reinitialize()
sim.advance_to_steady_state()
# Out:
# Initial Ethane concentration: [0.0121866]
# Half of initial concentration: [0.0060933]

# %%
# Create output files for sim that we can read in later:
outfile = open('results_ethane_2atm_equilib','w')

writer = csv.writer(outfile)
writer.writerow(gas.species_names)
writer.writerow(list(gas.concentrations))
# Out:
# 1083

# %%
data_2atm_equilib = pd.read_csv('results_ethane_2atm_equilib')
df_2atm_equilib = pd.DataFrame(data_2atm_equilib)

# %%
df_2atm_equilib.index = pd.Index(['concentration (kmol/m^3)'],name='species')

df_2atm_equilib_trans = df_2atm_equilib.T

df_2atm_equilib_trans.sort_values('concentration (kmol/m^3)', inplace=True, ascending=False)


print('Equilibrium concentrations:\n')
print(df_2atm_equilib_trans)
# Out:
# Equilibrium concentrations:
#
# species     concentration (kmol/m^3)
# CH4(15)                 8.994857e-03
# C2H4(38)                1.658806e-03
# C4H6(195)               5.311674e-04
# C3H6(95)                4.320962e-04
# H2(6)                   1.989794e-04
# C3H4(169)               1.056986e-04
# C3H4(167)               8.386624e-05
# C5H8(403)               7.759087e-05
# C2H6(36)                7.475932e-05
# C4H8(190)               1.136200e-05
# C4H8(189)               1.054509e-05
# propane(1)              5.404696e-06
# C5H10(541)              1.059470e-06
# C6H10(342)              1.710443e-07
# C4H6(770)               8.559662e-08
# C3H5-A(94)              8.457181e-08
# C5H7(404)               2.550890e-08
# C3H3(66)                1.994543e-08
# C4H7(191)               1.232794e-08
# CH3(14)                 2.885582e-09
# C4H5(107)               1.583984e-09
# C2H5(37)                3.173623e-10
# C5H9(399)               2.152013e-10
# C6H9(343)               1.131588e-10
# C2H3(41)                5.871786e-11
# C5H9(405)               4.419282e-11
# IC3H7(93)               4.214209e-11
# C3H5(101)               2.253544e-11
# C4H7(192)               1.574404e-11
# NC3H7(92)               1.489340e-11
# C4H5(106)               6.079870e-12
# H(2)                    3.517724e-12
# C5H9(400)               2.956825e-12
# C5H9(407)               2.027027e-12
# SC4H9(184)              1.391436e-12
# C5H9(428)               9.445176e-13
# PC4H9(183)              3.748907e-13
# IC4H9(273)              3.086423e-13
# C4H7(777)               2.471724e-13
# C4H5(781)               1.919659e-13
# C5H11(422)              8.745535e-14
# C4H7(193)               8.210963e-14
# C3H4(801)               7.693985e-14
# C5H11(537)              1.749217e-14
# C5H11(421)              1.493759e-14
# C5H11(540)              8.778108e-15
# C4H5(774)               1.004984e-15
# C4H5(793)               2.365990e-16
# Ne                      0.000000e+00
# He                      0.000000e+00

# %% [markdown]
# (g) If you switch from an isothermal to an adiabatic reactor, what happens to the ethene production? Why?

# %%
# get chemkin file and setup reactor
cti_file = '/home/chrisb/Documents/grad school/2019/_08_Advanced_kinetics/assignments/HW1/propanepyrolysis.cti'
gas = ct.Solution(cti_file)

# start with pure ethane:
X_Eth = 1

# Reactor conditions
time = 1
reactorTemperature = 1000  # Kelvin
reactorPressure = ct.one_atm
concentrations = {'C2H6(36)': X_Eth}
gas.TPX = reactorTemperature, reactorPressure, concentrations 
Eth_conc = gas['C2H6(36)'].concentrations
Eth_conc_half = Eth_conc/2

#initialize reactor, reactor network and sensitivities
atol = 1e-23
rtol = 1e-8
r1 = ct.ConstPressureReactor(contents=gas, energy='on', name='adiabatic_reactor')

sim = ct.ReactorNet([r1])
sim.atol = atol
sim.rtol = rtol
for i in range(gas.n_reactions):
     r1.add_sensitivity_reaction(i)

#check initial concentration
print('Initial Ethane concentration:', Eth_conc,'\nHalf of initial concentration:', Eth_conc_half)

# # Create output files for sim that we can read in later:
# outfile = open('results_ethane_adiabat','w')
# outfile2 = open('results_ethane_ROP_adiabat','w')
# outfile3 = open('results_sensitivity_adiabat', 'w')
# gas_production_label = [s + ' production rate' for s in gas.species_names]
# gas_concentration_label = [s + ' concentration' for s in gas.species_names]
# writer = csv.writer(outfile)
# writer2 = csv.writer(outfile2)
# writer3 = csv.writer(outfile3)
# writer.writerow(['Time (s)'] + gas.species_names + gas_concentration_label + gas_production_label)
# writer2.writerow(['Time (s)'] + gas.reactions())
# writer3.writerow(['Time (s)'] + gas.reactions())

# while sim.time < time:
#     sim.step()
#     print(sim.time)
#     writer.writerow([sim.time] + list(gas.X) + list(gas.concentrations)+list(gas.net_production_rates))
#     writer2.writerow([sim.time] + list(gas.net_rates_of_progress))
#     writer3.writerow([sim.time] + [sim.sensitivity('C2H6(36)', s) for s in range(gas.n_reactions)]) 


# Run the reactor
sim.advance_to_steady_state()
# Out:
# Initial Ethane concentration: [0.0121866]
# Half of initial concentration: [0.0060933]
# ---------------------------------------------------------------------------
# CanteraError                              Traceback (most recent call last)
# <ipython-input-185-d25fdba943cd> in <module>
#      51
#      52 # Run the reactor
# ---> 53 sim.advance_to_steady_state()
#
# interfaces/cython/cantera/reactor.pyx in cantera._cantera.ReactorNet.advance_to_steady_state()
#
# interfaces/cython/cantera/reactor.pyx in cantera._cantera.ReactorNet.step()
#
# CanteraError:
# ***********************************************************************
# CanteraError thrown by CVodesIntegrator::step:
# CVodes error encountered. Error code: -3
#
# At t = 2.47339 and h = 1.21308e-07, the error test failed repeatedly or with |h| = hmin.
# Components with largest weighted error estimates:
# 5: -48.2916
# 35: 36.5726
# 46: -35.9472
# 43: 35.5385
# 44: 29.3456
# 42: 25.2469
# 29: -18.4887
# 41: 13.4179
# 18: -13.318
# 48: -9.29307
# ***********************************************************************

# %%
# Create output files for sim that we can read in later:
data_2atm_equilib_ad = pd.read_csv('results_ethane_adiabat')
df_2atm_equilib_ad = pd.DataFrame(data_2atm_equilib_ad)

# %%
# plot concentration
plt1 = df_2atm_equilib_ad.plot(x='Time (s)', y='C2H6(36) concentration')
plt.show()

# %%
# Create output files for sim that we can read in later:
outfile = open('results_ethane_adiabat','w')

writer = csv.writer(outfile)
writer.writerow(gas.species_names)
writer.writerow(list(gas.concentrations))
# Out:
# 1123

# %%
data_2atm_equilib_ad = pd.read_csv('results_ethane_2atm_equilib_ad')
df_2atm_equilib_ad = pd.DataFrame(data_2atm_equilib_ad)

# %%
df_2atm_equilib_ad.index = pd.Index(['concentration (kmol/m^3)'],name='species')

df_2atm_equilib_ad_trans = df_2atm_equilib_ad.T

df_2atm_equilib_ad_trans.sort_values('concentration (kmol/m^3)', inplace=True, ascending=False)


print(gas.T)
print('Equilibrium concentrations:')
print('it looks like hardly and of the ethane is consumed :\n')
print(df_2atm_equilib_ad_trans)



#hardly any of the
# Out:
# 913.272596277824
# Equilibrium concentrations:
# it looks like hardly and of the ethane is consumed :
#
# species     concentration (kmol/m^3)
# C2H6(36)                1.218660e-02
# CH3(14)                 1.906829e-17
# C2H5(37)                6.057578e-21
# H(2)                    6.056385e-21
# CH4(15)                 1.134130e-24
# H2(6)                   2.974711e-26
# C2H4(38)                9.415494e-29
# propane(1)              2.820921e-39
# IC3H7(93)               8.935730e-44
# C2H3(41)                2.337614e-50
# C3H6(95)                2.506029e-51
# NC3H7(92)               2.070764e-51
# PC4H9(183)              1.867674e-55
# C4H8(189)               8.390614e-63
# SC4H9(184)              5.558372e-63
# C3H5-A(94)              9.179275e-68
# C4H8(190)               7.031255e-71
# C3H5(101)               4.683058e-72
# IC4H9(273)              2.111247e-73
# C5H11(540)              1.263803e-77
# C5H11(537)              5.772938e-78
# C5H11(422)              4.582724e-78
# C4H7(191)               3.352336e-79
# C3H4(167)               3.193338e-79
# C3H4(169)               3.114187e-80
# C4H7(192)               1.757601e-81
# C4H6(195)               1.479988e-83
# C4H7(193)               1.184460e-83
# C5H11(421)              5.859354e-85
# C4H7(777)               2.489007e-86
# C4H5(107)               3.253561e-88
# C4H5(106)               4.368494e-89
# C4H6(770)               8.915357e-92
# C3H4(801)               4.293420e-93
# C3H3(66)                3.557495e-95
# C4H5(781)               2.289864e-96
# C4H5(793)               1.674314e-96
# C4H5(774)               1.980712e-97
# C5H9(428)              7.755926e-103
# C5H9(400)              6.176884e-104
# C6H10(342)             4.083029e-104
# C5H9(407)              7.544840e-107
# C5H8(403)              3.276650e-108
# C5H9(405)              8.580635e-110
# C5H9(399)              1.858818e-110
# C5H10(541)             1.029040e-119
# C6H9(343)              3.628338e-121
# C5H7(404)              7.246091e-125
# Ne                      0.000000e+00
# He                      0.000000e+00
